# %% [markdown]
# <a href="https://colab.research.google.com/github/lopesmatheus/COA19-PythonSimu/blob/main/FMU_CTRL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fmpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 66.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 KB 13.8 MB/s eta 0:00:00
# ...

# %%
import fmpy
from fmpy import *

fmpy.plot_library = 'plotly'  # experimental


filename = 'CTRL_v3.fmu'

start_values = {
    # variable                                                 start   unit      description
    'Parameters.K_FAV_CTRL_BOOST_DEFAULT_VAL':                   1.0,        
    'Parameters.K_FAV_CTRL_BOOST_NEG_VAR_BOOST_ERR[0]':        -50.0,        
    'Parameters.K_FAV_CTRL_BOOST_NEG_VAR_BOOST_ERR[1]':        -30.0,        
    'Parameters.K_FAV_CTRL_BOOST_NEG_VAR_BOOST_ERR[2]':        -15.0,        
    'Parameters.K_FAV_CTRL_BOOST_NEG_VAR_BOOST_ERR[3]':          0.0,        
    'Parameters.K_FAV_CTRL_BOOST_NEG_VAR_BOOST_VAL[0]':          1.0,        
    'Parameters.K_FAV_CTRL_BOOST_NEG_VAR_BOOST_VAL[1]':          1.0,        
    'Parameters.K_FAV_CTRL_BOOST_NEG_VAR_BOOST_VAL[2]':          1.0,        
    'Parameters.K_FAV_CTRL_BOOST_NEG_VAR_BOOST_VAL[3]':          1.0,        
    'Parameters.K_FAV_CTRL_BOOST_NEG_VAR_DEGC':                -50.0,        
    'Parameters.K_FAV_CTRL_BOOST_NEG_VAR_DURATION_MS':        7000.0,        
    'Parameters.K_FAV_CTRL_BOOST_POS_VAR_BOOST_ERR[0]':          0.0,        
    'Parameters.K_FAV_CTRL_BOOST_POS_VAR_BOOST_ERR[1]':         15.0,        
    'Parameters.K_FAV_CTRL_BOOST_POS_VAR_BOOST_ERR[2]':         30.0,        
    'Parameters.K_FAV_CTRL_BOOST_POS_VAR_BOOST_ERR[3]':         50.0,        
    'Parameters.K_FAV_CTRL_BOOST_POS_VAR_BOOST_VAL[0]':          1.0,        
    'Parameters.K_FAV_CTRL_BOOST_POS_VAR_BOOST_VAL[1]':          1.0,        
    'Parameters.K_FAV_CTRL_BOOST_POS_VAR_BOOST_VAL[2]':          1.0,        
    'Parameters.K_FAV_CTRL_BOOST_POS_VAR_BOOST_VAL[3]':          1.0,        
    'Parameters.K_FAV_CTRL_BOOST_POS_VAR_DEGC':                 50.0,        
    'Parameters.K_FAV_CTRL_BOOST_POS_VAR_DURATION_MS':        7000.0,        
    'Parameters.K_FAV_CTRL_BOOST_TARGET_INIT_DEGC':            189.0,        
    'Parameters.K_FAV_CTRL_CMD_INIT_MA':                        55.0,        
    'Parameters.K_FAV_CTRL_CMD_MAX_MA':                        255.0,        
    'Parameters.K_FAV_CTRL_CMD_MIN_MA':                         55.0,        
    'Parameters.K_FAV_CTRL_CMD_ZA_COEF':                        -0.9,        
    'Parameters.K_FAV_CTRL_MIN_TARGET_DEGC':                   120.0,        
    'Parameters.K_FAV_CTRL_OBSV_A11':                        -10.971,        
    'Parameters.K_FAV_CTRL_OBSV_A12':                        -9.2385,        
    'Parameters.K_FAV_CTRL_OBSV_A13':                        0.10596,        
    'Parameters.K_FAV_CTRL_OBSV_A21':                         14.251,        
    'Parameters.K_FAV_CTRL_OBSV_A22':                         11.997,        
    'Parameters.K_FAV_CTRL_OBSV_A23':                       -0.12609,        
    'Parameters.K_FAV_CTRL_OBSV_A31':                         3.5567,        
    'Parameters.K_FAV_CTRL_OBSV_A32':                         2.7455,        
    'Parameters.K_FAV_CTRL_OBSV_A33':                        0.96835,        
    'Parameters.K_FAV_CTRL_OBSV_B11':                     -2.3707E-5,        
    'Parameters.K_FAV_CTRL_OBSV_B12':                       0.013343,        
    'Parameters.K_FAV_CTRL_OBSV_B13':                      -0.019393,        
    'Parameters.K_FAV_CTRL_OBSV_B21':                      3.0703E-5,        
    'Parameters.K_FAV_CTRL_OBSV_B22':                      -0.015888,        
    'Parameters.K_FAV_CTRL_OBSV_B23':                       0.023152,        
    'Parameters.K_FAV_CTRL_OBSV_B31':                     -2.3797E-7,        
    'Parameters.K_FAV_CTRL_OBSV_B32':                      -0.003964,        
    'Parameters.K_FAV_CTRL_OBSV_B33':                      0.0084778,        
    'Parameters.K_FAV_CTRL_OBSV_X1_INIT':                    -2.8265,        
    'Parameters.K_FAV_CTRL_OBSV_X2_INIT':                     3.8672,        
    'Parameters.K_FAV_CTRL_OBSV_X3_INIT':                     15.607,        
    'Parameters.K_FAV_CTRL_RATE_TARGET_DEGC_S':                  0.5,        
    'Parameters.Switch2_Threshold':                            500.0,        
    'Parameters.Switch1_Threshold':                           1000.0,        
    'Parameters.Switch3_Threshold':                           1500.0,        
    'Parameters.Switch4_Threshold':                           2000.0,        
    'Parameters.Switch5_Threshold':                           2500.0,        
    'Parameters.Constant3_Value':                              200.0,        
    'Parameters.Constant2_Value':                              230.0,        
    'Parameters.Constant1_Value':                              200.0,        
    'Parameters.Constant19_Value':                             230.0,        
    'Parameters.Constant15_Value':                             200.0,        
    'Parameters.Constant12_Value':                             200.0,        
    'Parameters.Switch6_Threshold':                              0.0,        
    'Parameters.Constant6_Value':                                  0,        
    'Parameters.Constant6_Value_i':                                0,        
    'Parameters.Constant7_Value':                                  0,        
    'Parameters.Constant7_Value_b':                                0,        
    'Parameters.UnitDelay2_InitialCondition':                      0,        
    'Parameters.UnitDelay2_InitialCondition_a':                    0,        
    'Parameters.CST_SING_Value':                                 0.0,        
    'Parameters.CST_CP_Value':                                  0.05,        
    'Parameters.UnitDelay_InitialCondition':                     0.0,        
    'Parameters.CST_CP6_Value':                                  1.0,        
    'Parameters.ITM_FAV__mA4_Gain':                              1.0,        
    'Parameters.CST_CP7_Value':                                  1.0,        
    'Parameters.ITM_FAV__mA3_Gain':                              1.0,        
    'Parameters.ITM_FAV__mA2_Gain':                              1.0,        
    'Parameters.CST_CP5_Value':                                 0.05,        
    'Parameters.CST_CP11_Value':                                 1.0,        
    'Parameters.ITM_FAV__mA1_Gain':                              1.0,        
    'Parameters.CST_CP13_Value':                                 1.0,        
    'Parameters.ITM_FAV__mA17_Gain':                             1.0,        
    'Parameters.Constant1_Value_n':                             25.0,        
    'Parameters.Constant4_Value':                               50.0,        
    'Parameters.PIT_Period_in_msec_Value':                      25.0,        
    'Parameters.Constant1_Value_g':                             25.0,        
    'Parameters.Constant4_Value_b':                             50.0,        
    'Parameters.PIT_Period_in_msec_Value_d':                    25.0,        
    'Parameters.CST_CP8_Value':                                  1.0,        
    'Parameters.CST_CP9_Value':                                152.0,        
    'Parameters.CST_SING_Value_a':                            1000.0,        
    'Parameters.CST_SING3_Value':                            -899.42,        
    'Parameters.CST_SING4_Value':                        -694.426575,        
    'Parameters.CST_SING6_Value':                             7.9053,        
    'Parameters.ITM_FAV__mA7_Gain':                              0.0,        
    'Parameters.ITM_FAV__mA11_Gain':                             1.0,        
    'Parameters.ITM_FAV__mA16_Gain':                            -1.0,        
    'Parameters.UnitDelay_InitialCondition_b':                   0.0,        
    'Parameters.UnitDelay_InitialCondition_d':                   0.0,        
    'Parameters.UnitDelay_InitialCondition_k':                   0.0,        
    'Parameters.UnitDelay_InitialCondition_j':                   0.0,        
    'Parameters.UnitDelay_InitialCondition_i':                   0.0,        
    'Parameters.ITM_FAV__mA13_Gain':                             1.0,        
    'Parameters.CST_SING_Value_c':                               0.0,        
    'Parameters.UnitDelay_InitialCondition_h':                   0.0,        
    'Parameters.UnitDelay_InitialCondition_bs':                  0.0,        
    'Parameters.UnitDelay_InitialCondition_n':                   0.0,        
    'Parameters.UnitDelay_InitialCondition_c':                   0.0,        
    'Parameters.Constant2_Value_b':                            False,        
    'Parameters.CST_FALSE_Value':                              False,        
    'Parameters.Constant1_Value_f':                            False,        
    'Parameters.Constant12_Value_c':                           False,        
    'Parameters.UnitDelay1_InitialCondition':                  False,        
    'Parameters.UnitDelay_InitialCondition_a':                 False,        
    'Parameters.UnitDelay1_InitialCondition_b':                False,        
    'Parameters.UnitDelay2_InitialCondition_a1':               False,        
    'Parameters.Constant_Value':                               False,        
    'Parameters.Constant1_Value_d':                            False,        
    'Parameters.Constant14_Value':                             False,        
    'Parameters.Constant1_Value_a':                            False,        
    'Parameters.CST_FALSE1_Value':                             False,        
    'Parameters.CST_FALSE4_Value':                             False,        
    'Parameters.Constant2_Value_l':                            False,        
    'Parameters.UnitDelay1_InitialCondition_m':                False,        
    'Parameters.UnitDelay_InitialCondition_du':                False,        
    'Parameters.UnitDelay1_InitialCondition_l':                False,        
    'Parameters.UnitDelay_InitialCondition_f':                 False,        
    'Parameters.UnitDelay1_InitialCondition_d':                False,        
    'Parameters.UnitDelay1_InitialCondition_bp':               False,        
    'Parameters.UnitDelay1_InitialCondition_o':                False,        
    'Parameters.UnitDelay1_InitialCondition_f':                False,        
    'Parameters.UnitDelay1_InitialCondition_by':               False,        
    'Parameters.Constant_Value_i':                             False,        
    'Parameters.Constant_Value_n':                             False,        
    'Parameters.Constant_Value_nd':                            False,        
    'Parameters.Constant_Value_k':                             False,        
    'Parameters.Constant_Value_o':                             False,        
    'Parameters.Constant1_Value_c':                            False,        
    'Parameters.Constant1_Value_d3':                           False,        
    'Parameters.Constant_Value_im':                            False,        
    'Parameters.UnitDelay1_InitialCondition_a':                False,        
    'Parameters.Constant_Value_iq':                            False,        
    'Parameters.UnitDelay1_InitialCondition_lx':               False,        
    'Parameters.Constant_Value_f':                             False,        
    'Parameters.UnitDelay1_InitialCondition_me':               False,        
    'Parameters.UnitDelay1_InitialCondition_n':                False,        
    'Parameters.Constant_Value_oo':                            False,        
}

output = [
    'SW_FAV_CTRL_CMD',
]

result = simulate_fmu(filename, start_values=start_values, output=output, stop_time=100.0)

plot_result(result)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
